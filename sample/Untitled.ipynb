# %%
from streetscape import generate_grids, graph2gdf
# imports
import osmnx as ox
import nest_asyncio
nest_asyncio.apply()

# %load_ext autoreload

# %autoreload 2

# %%
osm_street = ox.graph_from_place('Haywards Heath, UK')

# %%
streets = graph2gdf(osm_street)

# %%
grids = generate_grids(streets, distance=20)
# Out:
# 35063 grid points created

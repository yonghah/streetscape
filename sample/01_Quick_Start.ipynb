# %% [markdown]
# # Get Street Views

# %%
import streetscape as ss
# %matplotlib inline

# %%
# This will create the mid points of each street.
obs = ss.create_observation_points('Haywards Heath, UK')

# %%
obs.plot()
obs.tail()
# Out:
#                                           obs_point
# 4480                  POINT (-0.1066429 50.9993572)
# 4481  POINT (-0.1065518890254224 50.99925581267403)
# 4482           POINT (-0.1069065 50.99932769999999)
# 4483          POINT (-0.10655535 50.99942919999999)
# 4484  POINT (-0.1064415062430318 50.99938275424201)

# %%
# %env GSV_API_KEY=YOUR_API_KEY
# Out:
# env: GSV_API_KEY=YOUR_API_KEY

# %%
output_dir = 'output'
df = obs.tail() # only five observation points
ss.get_street_views_from_df(df, output_dir)
